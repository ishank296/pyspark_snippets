# %% [markdown]
# ### Using udf decorator

# %%
@udf("double")
def multiply_2(v):
  return v * 2

# %%
from pyspark.sql.functions import col,rand
df = spark.range(0,1000).withColumn('v',(col('id')*rand()*100).cast('double'))
df = df.withColumn('v_2',multiply_2(df.v))
display(df.take(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>v</th><th>v_2</th></tr></thead><tbody><tr><td>0</td><td>0.0</td><td>0.0</td></tr><tr><td>1</td><td>30.797280132706284</td><td>61.59456026541257</td></tr><tr><td>2</td><td>34.9986172455228</td><td>69.9972344910456</td></tr><tr><td>3</td><td>64.49880226644699</td><td>128.99760453289397</td></tr><tr><td>4</td><td>206.97821282555523</td><td>413.95642565111046</td></tr><tr><td>5</td><td>227.70688306516206</td><td>455.4137661303241</td></tr><tr><td>6</td><td>180.82002439991217</td><td>361.64004879982434</td></tr><tr><td>7</td><td>190.67145336851848</td><td>381.34290673703697</td></tr><tr><td>8</td><td>786.5968604563585</td><td>1573.193720912717</td></tr><tr><td>9</td><td>59.660617950389415</td><td>119.32123590077883</td></tr></tbody></table></div>

# %% [markdown]
# ### Alternate syntax register throught Sparksession

# %%
from pyspark.sql.types import DoubleType

# %%
def add_one(v):
  return v + 1

spark.udf.register("plus_one",add_one,DoubleType())

display(df.selectExpr('id','plus_one(v) as v').take(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>v</th></tr></thead><tbody><tr><td>0</td><td>1.0</td></tr><tr><td>1</td><td>31.797280132706284</td></tr><tr><td>2</td><td>35.9986172455228</td></tr><tr><td>3</td><td>65.49880226644699</td></tr><tr><td>4</td><td>207.97821282555523</td></tr><tr><td>5</td><td>228.70688306516206</td></tr><tr><td>6</td><td>181.82002439991217</td></tr><tr><td>7</td><td>191.67145336851848</td></tr><tr><td>8</td><td>787.5968604563585</td></tr><tr><td>9</td><td>60.660617950389415</td></tr></tbody></table></div>

# %% [markdown]
# ### pandas vectorized udf

# %%
from pyspark.sql.functions import pandas_udf


@pandas_udf('double')
def subtract_one(v):
  return v -1

display(df.select(col('id'),subtract_one(col('v')).alias('v')).take(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>v</th></tr></thead><tbody><tr><td>0</td><td>-1.0</td></tr><tr><td>1</td><td>29.797280132706284</td></tr><tr><td>2</td><td>33.9986172455228</td></tr><tr><td>3</td><td>63.49880226644699</td></tr><tr><td>4</td><td>205.97821282555523</td></tr><tr><td>5</td><td>226.70688306516206</td></tr><tr><td>6</td><td>179.82002439991217</td></tr><tr><td>7</td><td>189.67145336851848</td></tr><tr><td>8</td><td>785.5968604563585</td></tr><tr><td>9</td><td>58.660617950389415</td></tr></tbody></table></div>
